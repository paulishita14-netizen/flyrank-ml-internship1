# %% [markdown]
# <a href="https://colab.research.google.com/github/paulishita14-netizen/flyrank-ml-internship1/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/paulishita14-netizen/flyrank-ml-internship1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !git clone https://github.com/paulishita14-netizen/flyrank-ml-internship1.git
# Out:
# Cloning into 'flyrank-ml-internship1'...
# remote: Enumerating objects: 120, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 120 (delta 35), reused 98 (delta 29), pack-reused 0 (from 0)
# Receiving objects: 100% (120/120), 1.93 MiB | 15.53 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %%
import pandas as pd

# Load the dataset from the path you can now see in your file sidebar
file_path = 'flyrank-ml-internship1/data/raw/content_refresh_anonymized.csv'
df = pd.read_csv(file_path)

# Display the first few rows to understand the structure
print(df.head())
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Choose your lane and explain why it matters (e.g., "I am choosing the Content Optimization lane because this dataset allows me to analyze how word_count and main_intent influence avg_position").

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# The Question: Define a clear question, such as: "Can we predict if a keyword article will achieve a striking position_tier based on its word_count and search_volume?"
#
# Decision/Action: State what decision this improves (e.g., "Deciding which content to refresh") and the action taken (e.g., "Updating the word_count or optimizing the main_intent

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
# Example: Check how many items are currently in 'page_3_5' vs 'striking'
position_counts = df['position_tier'].value_counts()
print(position_counts)

# Example: Average search volume for pages in the 'striking' tier
striking_avg_vol = df[df['position_tier'] == 'striking']['search_volume'].mean()
print(f"Average search volume for 'striking' pages: {striking_avg_vol}")
# Out:
# position_tier
# page_1      11814
# striking     7304
# page_3_5     7242
# top_3        2321
# deep         1319
# Name: count, dtype: int64
# Average search volume for 'striking' pages: 149.00113346557097

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# "My analysis provides observed and measured insights into the relationship between content features (such as word_count and main_intent) and their directional impact on search positioning. This work is intended for decision-support to help prioritize content for potential refresh efforts. I will not make claims regarding causal proof, nor will I attempt to claim that I am 'predicting Google's algorithm' or uncovering its ranking logic."

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# -[ ] Every section is filled (Markdown thoughts + supporting code).
#
# -[ ] The notebook runs top to bottom without errors (use Runtime → Run all to verify).
#
# -[ ] You have removed any private or sensitive information.
#
# -[ ] Your language uses "careful words" as drafted above.
#
# -[ ] Everything is committed to 'work/notebooks/.'
